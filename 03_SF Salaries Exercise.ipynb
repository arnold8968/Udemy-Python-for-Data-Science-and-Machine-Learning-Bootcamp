# %%
import numpy as np
import pandas as pd

# %%
sal = pd.read_csv('./dataset/Salaries.csv')
sal.head()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (3,4,5,6,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#   BasePay OvertimePay OtherPay Benefits   TotalPay  TotalPayBenefits  Year  \
# 0  167411           0   400184      NaN  567595.43         567595.43  2011
# 1  155966      245132   137811      NaN  538909.28         538909.28  2011
# ...

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
sal_new = sal[sal['BasePay'] != 'Not Provided']

# %%
sal_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148650 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148650 non-null  int64
#  1   EmployeeName      148650 non-null  object
#  2   JobTitle          148650 non-null  object
#  3   BasePay           148045 non-null  object
#  4   OvertimePay       148650 non-null  object
#  5   OtherPay          148650 non-null  object
#  6   Benefits          112491 non-null  object
#  7   TotalPay          148650 non-null  float64
#  8   TotalPayBenefits  148650 non-null  float64
#  9   Year              148650 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148650 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 15.9+ MB

# %%
sal_new['BasePay'] = sal_new['BasePay'].astype("float")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sal_new['BasePay'].astype("float").mean()
# Out:
# 66325.44884050643

# %%
sal_new['OvertimePay'].astype('float').max()
# Out:
# 245131.88

# %%
sal_new[sal_new['EmployeeName'] == 'JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
sal_new[sal_new['EmployeeName'] == 'JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
sal_new.sort_values('TotalPayBenefits', ascending=False).loc[0:0]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay OvertimePay OtherPay Benefits   TotalPay  TotalPayBenefits  Year  \
# 0  167411.18           0   400184      NaN  567595.43         567595.43  2011
#
#    Notes         Agency Status
# 0    NaN  San Francisco    NaN

# %%
sal_new[sal_new['TotalPayBenefits'] == sal_new['TotalPayBenefits'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay OvertimePay OtherPay Benefits   TotalPay  TotalPayBenefits  Year  \
# 0  167411.18           0   400184      NaN  567595.43         567595.43  2011
#
#    Notes         Agency Status
# 0    NaN  San Francisco    NaN

# %%
sal_new.iloc[0]
# Out:
# Id                                                               1
# EmployeeName                                        NATHANIEL FORD
# JobTitle            GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# BasePay                                                     167411
# OvertimePay                                                      0
# OtherPay                                                    400184
# Benefits                                                       NaN
# TotalPay                                                    567595
# TotalPayBenefits                                            567595
# Year                                                          2011
# Notes                                                          NaN
# Agency                                               San Francisco
# Status                                                         NaN
# Name: 0, dtype: object

# %%
sal_new.loc[sal_new['TotalPayBenefits'].idxmax()]
# Out:
# Id                                                               1
# EmployeeName                                        NATHANIEL FORD
# JobTitle            GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# BasePay                                                     167411
# OvertimePay                                                      0
# OtherPay                                                    400184
# Benefits                                                       NaN
# TotalPay                                                    567595
# TotalPayBenefits                                            567595
# Year                                                          2011
# Notes                                                          NaN
# Agency                                               San Francisco
# Status                                                         NaN
# Name: 0, dtype: object

# %%
sal_new.iloc[sal_new['TotalPayBenefits'].argmin()]
# Out:
# Id                                      148654
# EmployeeName                         Joe Lopez
# JobTitle            Counselor, Log Cabin Ranch
# BasePay                                      0
# OvertimePay                               0.00
# OtherPay                               -618.13
# Benefits                                  0.00
# TotalPay                               -618.13
# TotalPayBenefits                       -618.13
# Year                                      2014
# Notes                                      NaN
# Agency                           San Francisco
# Status                                      PT
# Name: 148653, dtype: object

# %%
sal_new[sal_new['TotalPayBenefits'] == sal['TotalPayBenefits'].min()]
# Out:
#             Id EmployeeName                    JobTitle  BasePay OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0        0.00
#
#        OtherPay Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653  -618.13     0.00   -618.13           -618.13  2014    NaN
#
#                Agency Status
# 148653  San Francisco     PT

# %%
sal_new.sort_values('TotalPayBenefits', ascending=True).reset_index().loc[0:0]
# Out:
#     index      Id EmployeeName                    JobTitle  BasePay  \
# 0  148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0
#
#   OvertimePay OtherPay Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 0        0.00  -618.13     0.00   -618.13           -618.13  2014    NaN
#
#           Agency Status
# 0  San Francisco     PT

# %%
sal_new
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148645  148646   Carolyn A Wilson
# 148647  148648     Joann Anderson
# 148648  148649        Leon Walker
# 148649  148650      Roy I Tillery
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18           0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02      245132
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13      106088
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.7
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60        9737
# ...                                                ...        ...         ...
# ...

# %%
sal_new.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
sal_new.groupby('Year').mean()['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
len(sal_new['JobTitle'].unique())
# Out:
# 2158

# %%
sal_new['JobTitle'].nunique()
# Out:
# 2158

# %%
sal_new[['JobTitle', 'Id']].groupby('JobTitle').count()
# Out:
#                                                  Id
# JobTitle
# ACCOUNT CLERK                                    83
# ACCOUNTANT                                        5
# ACCOUNTANT INTERN                                48
# ACPO,JuvP, Juv Prob (SFERS)                       1
# ACUPUNCTURIST                                     1
# ...                                             ...
# X-RAY LABORATORY AIDE                            26
# X-Ray Laboratory Aide                           100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    1
# Youth Comm Advisor                                4
# ZOO CURATOR                                       1
#
# [2158 rows x 1 columns]

# %%
sal_new[['JobTitle', 'Id']].groupby('JobTitle').count().rename(columns = {'Id': 'Count'}).sort_values('Count', ascending = False).head()
# Out:
#                               Count
# JobTitle
# Transit Operator               7036
# Special Nurse                  4389
# Registered Nurse               3736
# Public Svc Aide-Public Works   2518
# Police Officer 3               2421

# %%
sal_new['JobTitle'].value_counts().head()
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
sal_new[sal_new['Year'] == 2013].groupby('JobTitle').count() < 2
# Out:
#                                    Id  EmployeeName  BasePay  OvertimePay  \
# JobTitle
# ASR Senior Office Specialist    False         False    False        False
# ASR-Office Assistant            False         False    False        False
# Account Clerk                   False         False    False        False
# Accountant I                    False         False    False        False
# Accountant II                   False         False    False        False
# ...                               ...           ...      ...          ...
# Wire Rope Cable Maint Sprv       True          True     True         True
# Worker's Comp Supervisor 1      False         False    False        False
# Worker's Compensation Adjuster  False         False    False        False
# X-Ray Laboratory Aide           False         False    False        False
# Youth Comm Advisor              False         False    False        False
#
#                                 OtherPay  Benefits  TotalPay  \
# ...

# %%
one_person = sal_new[sal_new['Year'] == 2013].groupby('JobTitle').count() < 2

# %%
one_person['Id']
# Out:
# JobTitle
# ASR Senior Office Specialist      False
# ASR-Office Assistant              False
# Account Clerk                     False
# Accountant I                      False
# Accountant II                     False
#                                   ...
# Wire Rope Cable Maint Sprv         True
# Worker's Comp Supervisor 1        False
# Worker's Compensation Adjuster    False
# X-Ray Laboratory Aide             False
# Youth Comm Advisor                False
# Name: Id, Length: 1051, dtype: bool

# %%
sal_2013 = sal_new[sal_new['Year'] == 2013].groupby('JobTitle').count()

# %%
sal_2013[one_person['Id']]
# Out:
#                                Id  EmployeeName  BasePay  OvertimePay  \
# JobTitle
# Acupuncturist                   1             1        1            1
# Adm, SFGH Medical Center        1             1        1            1
# Administrative Analyst I        1             1        1            1
# Administrative Analyst II       1             1        1            1
# Administrator, DPH              1             1        1            1
# ...                            ..           ...      ...          ...
# Victim & Witness Technician     1             1        1            1
# Water Meter Shop Supervisor 1   1             1        1            1
# Wharfinger 1                    1             1        1            1
# Window Cleaner Supervisor       1             1        1            1
# Wire Rope Cable Maint Sprv      1             1        1            1
#
#                                OtherPay  Benefits  TotalPay  TotalPayBenefits  \
# JobTitle
# ...

# %%
len(sal_2013[one_person['Id']])
# Out:
# 202

# %%
sum(sal_new[sal_new['Year'] == 2013]['JobTitle'].value_counts() == 1)
# Out:
# 202

# %%
sal_new
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148645  148646   Carolyn A Wilson
# 148647  148648     Joann Anderson
# 148648  148649        Leon Walker
# 148649  148650      Roy I Tillery
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18           0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02      245132
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13      106088
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.7
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60        9737
# ...                                                ...        ...         ...
# ...

# %%
'GENERAL' in sal_new['JobTitle'][0]
# Out:
# True

# %%
job = sal_new['JobTitle']

# %%
job
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148645                         Human Services Technician
# 148647                       Communications Dispatcher 2
# 148648                                         Custodian
# 148649                                         Custodian
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148650, dtype: object

# %%
num = 0
for i in job:
    if 'Chief' in i:
        print(i)
        num += 1
# Out:
# Chief of Police
# Chief, Fire Department
# Battlion Chief, Fire Suppressi
# Battlion Chief, Fire Suppressi
# Battlion Chief, Fire Suppressi
# Battlion Chief, Fire Suppressi
# Assistant Deputy Chief 2
# Assistant Deputy Chief 2
# Deputy Chief 3
# Assistant Deputy Chief 2
# Deputy Chief 3
# Deputy Chief 3
# Battlion Chief, Fire Suppressi
# Deputy Chief 3
# Battlion Chief, Fire Suppressi
# Battlion Chief, Fire Suppressi
# Battlion Chief, Fire Suppressi
# Battlion Chief, Fire Suppressi
# Battlion Chief, Fire Suppressi
# Battlion Chief, Fire Suppressi
# Battlion Chief, Fire Suppressi
# Battlion Chief, Fire Suppressi
# Assistant Deputy Chief 2
# Emergency Medical Svcs Chief
# Deputy Chief 3
# Battlion Chief, Fire Suppressi
# Battlion Chief, Fire Suppressi
# Deputy Chief 3
# Battlion Chief, Fire Suppressi
# Battlion Chief, Fire Suppressi
# Battlion Chief, Fire Suppressi
# Battlion Chief, Fire Suppressi
# Chief Atty1 (Civil & Criminal)
# Battlion Chief, Fire Suppressi
# ...

# %%
num
# Out:
# 423

# %%
def chief_string(title):
    if 'chief' in title.lower().split():
        return True
    else:
        return False

# %%
sal_new['JobTitle'].apply(lambda x: chief_string(x))
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 148645    False
# 148647    False
# 148648    False
# 148649    False
# 148653    False
# Name: JobTitle, Length: 148650, dtype: bool

# %%
sum(sal_new['JobTitle'].apply(lambda x: chief_string(x)))
# Out:
# 477

# %%
sal_new['title_len'] = sal_new['JobTitle'].apply(len)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sal_new[['JobTitle', 'title_len']]
# Out:
#                                               JobTitle  title_len
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY         46
# 1                      CAPTAIN III (POLICE DEPARTMENT)         31
# 2                      CAPTAIN III (POLICE DEPARTMENT)         31
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         36
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)         44
# ...                                                ...        ...
# 148645                       Human Services Technician         25
# 148647                     Communications Dispatcher 2         27
# 148648                                       Custodian          9
# 148649                                       Custodian          9
# 148653                      Counselor, Log Cabin Ranch         26
#
# [148650 rows x 2 columns]

# %%
sal_new[['JobTitle', 'title_len']].corr()
# Out:
#            title_len
# title_len        1.0

# %%
sal_new[['TotalPayBenefits', 'title_len']].corr()
# Out:
#                   TotalPayBenefits  title_len
# TotalPayBenefits           1.00000   -0.03692
# title_len                 -0.03692    1.00000
